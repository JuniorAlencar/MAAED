# %%
import numpy as np
import networkx  as nx
import matplotlib.pyplot as plt
import pandas as pd
from time import process_time

# %%
# Open requeriments file
df = pd.read_csv("../data/requirements.csv")
df
# Out:
#                     package     requirement  package_name package_version
# 0         02exercicio-1.0.0             NaN   02exercicio           1.0.0
# 1           0x10c-asm-0.0.2             NaN     0x10c-asm           0.0.2
# 2          115wangpan-0.7.6  beautifulsoup4    115wangpan           0.7.6
# 3          115wangpan-0.7.6          homura    115wangpan           0.7.6
# 4          115wangpan-0.7.6        humanize    115wangpan           0.7.6
# ...                     ...             ...           ...             ...
# 110099            zzr-1.0.0             NaN           zzr           1.0.0
# 110100            zzz-0.0.2             NaN           zzz           0.0.2
# 110101  zzzeeksphinx-1.0.18            mako  zzzeeksphinx          1.0.18
# 110102  zzzeeksphinx-1.0.18          pyscss  zzzeeksphinx          1.0.18
# 110103            zzzfs-0.1             NaN         zzzfs             0.1
#
# [110104 rows x 4 columns]

# %%
# replace 0 where "NaN" data
df["requirement"].fillna(0,inplace=True)
df["package_name"].fillna(0,inplace=True)

# %%
df
# Out:
#                     package     requirement  package_name package_version
# 0         02exercicio-1.0.0               0   02exercicio           1.0.0
# 1           0x10c-asm-0.0.2               0     0x10c-asm           0.0.2
# 2          115wangpan-0.7.6  beautifulsoup4    115wangpan           0.7.6
# 3          115wangpan-0.7.6          homura    115wangpan           0.7.6
# 4          115wangpan-0.7.6        humanize    115wangpan           0.7.6
# ...                     ...             ...           ...             ...
# 110099            zzr-1.0.0               0           zzr           1.0.0
# 110100            zzz-0.0.2               0           zzz           0.0.2
# 110101  zzzeeksphinx-1.0.18            mako  zzzeeksphinx          1.0.18
# 110102  zzzeeksphinx-1.0.18          pyscss  zzzeeksphinx          1.0.18
# 110103            zzzfs-0.1               0         zzzfs             0.1
#
# [110104 rows x 4 columns]

# %%
# Remove all elements without requirement
requi_0 = [i for i in range(len(df)) if df["requirement"].values[i]==0]
df = df.drop(requi_0)

# %%
df
# Out:
#                        package     requirement      package_name  \
# 2             115wangpan-0.7.6  beautifulsoup4        115wangpan
# 3             115wangpan-0.7.6          homura        115wangpan
# 4             115wangpan-0.7.6        humanize        115wangpan
# 5             115wangpan-0.7.6          pycurl        115wangpan
# 6             115wangpan-0.7.6         pysocks        115wangpan
# ...                        ...             ...               ...
# 110094  zymbit-trequests-0.9.5        requests  zymbit-trequests
# 110095  zymbit-trequests-0.9.5         tornado  zymbit-trequests
# 110096  zymbit-trequests-0.9.5        tornalet  zymbit-trequests
# 110101     zzzeeksphinx-1.0.18            mako      zzzeeksphinx
# 110102     zzzeeksphinx-1.0.18          pyscss      zzzeeksphinx
#
#        package_version
# 2                0.7.6
# 3                0.7.6
# 4                0.7.6
# 5                0.7.6
# 6                0.7.6
# ...                ...
# 110094           0.9.5
# 110095           0.9.5
# 110096           0.9.5
# 110101          1.0.18
# 110102          1.0.18
#
# [73773 rows x 4 columns]

# %%
# Separate sites with package_name and without package_name
list_r_1 = []
list_r_2 = []
for i in range(len(df)):
    if(df["package_name"].values[i]==0):
        list_r_1.append(i)
    else:
        list_r_2.append(i)

# %%
# Create unique values with nodes
list_1 = [df["package_name"].values[i] for i in list_r_2]
list_2 = [df["package"].values[i] for i in list_r_1]
list_3 = [df["requirement"].values[i] for i in range(len(df))]
list_tot = np.unique(list_1+list_2+list_3)

# %%
df_data_index = [str('{:0{width}d}'.format(i, width=5)) for i in range(0,len(list_tot))]
df_data_node = [i for i in list_tot]
data1 = {"index":df_data_index,"package":df_data_node}
df_nodes = pd.DataFrame(data=data1)
df_nodes.to_csv("../data/nodes.csv",index=False,mode="w")

# %%
df_nodes
# Out:
#        index              package
# 0      00000                    -
# 1      00001  -allow-all-external
# 2      00002      -allow-external
# 3      00003    -allow-unverified
# 4      00004        -always-unzip
# ...      ...                  ...
# 26389  26389               zygote
# 26390  26390               zymbit
# 26391  26391       zymbit-connect
# 26392  26392     zymbit-trequests
# 26393  26393         zzzeeksphinx
#
# [26394 rows x 2 columns]

# %%
edge_pack = []
edge_requi = df["requirement"]

for i in range(len(df)):
    if(df["package_name"].values[i]==0):
        edge_pack.append(df["package"].values[i])
    else:
        edge_pack.append(df["package_name"].values[i])
data2 = {"package":edge_pack,"requirement":edge_requi}
df_edge = pd.DataFrame(data=data2)
#df_edge.to_csv("../data/edges.csv",index=False,mode="w")

# %%
# Pairwise nodes with code in nodes.csv
N = len(df_nodes)
for i in range(N):
    t1_start = process_time() 
    index_element = df_nodes["index"].iloc[(df_nodes['package'] == df_nodes.iloc[i,1]).idxmax()]
    df_edge.replace(to_replace=df_nodes.iloc[i,1],value=index_element,inplace=True)
    t1_stop = process_time()
    print(f"i={i},rest={N-i}, time_1_process = {t1_stop - t1_start}")
# Out:
# i=0,rest=26394, time_1_process = 0.0
# i=1,rest=26393, time_1_process = 0.015625
# i=2,rest=26392, time_1_process = 0.015625
# i=3,rest=26391, time_1_process = 0.0
# i=4,rest=26390, time_1_process = 0.015625
# i=5,rest=26389, time_1_process = 0.0
# i=6,rest=26388, time_1_process = 0.015625
# i=7,rest=26387, time_1_process = 0.0
# i=8,rest=26386, time_1_process = 0.015625
# i=9,rest=26385, time_1_process = 0.0
# i=10,rest=26384, time_1_process = 0.015625
# i=11,rest=26383, time_1_process = 0.0
# i=12,rest=26382, time_1_process = 0.0
# i=13,rest=26381, time_1_process = 0.015625
# i=14,rest=26380, time_1_process = 0.0
# i=15,rest=26379, time_1_process = 0.015625
# i=16,rest=26378, time_1_process = 0.0
# i=17,rest=26377, time_1_process = 0.015625
# i=18,rest=26376, time_1_process = 0.0
# i=19,rest=26375, time_1_process = 0.015625
# i=20,rest=26374, time_1_process = 0.0
# i=21,rest=26373, time_1_process = 0.015625
# i=22,rest=26372, time_1_process = 0.0
# i=23,rest=26371, time_1_process = 0.0
# i=24,rest=26370, time_1_process = 0.015625
# i=25,rest=26369, time_1_process = 0.0
# i=26,rest=26368, time_1_process = 0.015625
# i=27,rest=26367, time_1_process = 0.0
# i=28,rest=26366, time_1_process = 0.015625
# i=29,rest=26365, time_1_process = 0.0
# i=30,rest=26364, time_1_process = 0.015625
# i=31,rest=26363, time_1_process = 0.0
# i=32,rest=26362, time_1_process = 0.015625
# i=33,rest=26361, time_1_process = 0.0
# i=34,rest=26360, time_1_process = 0.0
# i=35,rest=26359, time_1_process = 0.015625
# i=36,rest=26358, time_1_process = 0.0
# i=37,rest=26357, time_1_process = 0.015625
# i=38,rest=26356, time_1_process = 0.0
# i=39,rest=26355, time_1_process = 0.015625
# i=40,rest=26354, time_1_process = 0.0
# i=41,rest=26353, time_1_process = 0.015625
# i=42,rest=26352, time_1_process = 0.0
# i=43,rest=26351, time_1_process = 0.015625
# i=44,rest=26350, time_1_process = 0.0
# i=45,rest=26349, time_1_process = 0.015625
# i=46,rest=26348, time_1_process = 0.0
# i=47,rest=26347, time_1_process = 0.015625
# i=48,rest=26346, time_1_process = 0.0
# i=49,rest=26345, time_1_process = 0.0
# i=50,rest=26344, time_1_process = 0.015625
# i=51,rest=26343, time_1_process = 0.0
# i=52,rest=26342, time_1_process = 0.015625
# i=53,rest=26341, time_1_process = 0.0
# i=54,rest=26340, time_1_process = 0.015625
# i=55,rest=26339, time_1_process = 0.0
# i=56,rest=26338, time_1_process = 0.015625
# i=57,rest=26337, time_1_process = 0.0
# i=58,rest=26336, time_1_process = 0.015625
# i=59,rest=26335, time_1_process = 0.0
# i=60,rest=26334, time_1_process = 0.0
# i=61,rest=26333, time_1_process = 0.015625
# i=62,rest=26332, time_1_process = 0.0
# i=63,rest=26331, time_1_process = 0.015625
# i=64,rest=26330, time_1_process = 0.0
# i=65,rest=26329, time_1_process = 0.015625
# i=66,rest=26328, time_1_process = 0.0
# i=67,rest=26327, time_1_process = 0.015625
# i=68,rest=26326, time_1_process = 0.0
# i=69,rest=26325, time_1_process = 0.0
# i=70,rest=26324, time_1_process = 0.015625
# i=71,rest=26323, time_1_process = 0.0
# i=72,rest=26322, time_1_process = 0.015625
# i=73,rest=26321, time_1_process = 0.0
# i=74,rest=26320, time_1_process = 0.015625
# i=75,rest=26319, time_1_process = 0.0
# i=76,rest=26318, time_1_process = 0.015625
# i=77,rest=26317, time_1_process = 0.0
# i=78,rest=26316, time_1_process = 0.015625
# i=79,rest=26315, time_1_process = 0.0
# i=80,rest=26314, time_1_process = 0.0
# i=81,rest=26313, time_1_process = 0.015625
# i=82,rest=26312, time_1_process = 0.0
# i=83,rest=26311, time_1_process = 0.015625
# i=84,rest=26310, time_1_process = 0.0
# i=85,rest=26309, time_1_process = 0.015625
# i=86,rest=26308, time_1_process = 0.0
# i=87,rest=26307, time_1_process = 0.015625
# i=88,rest=26306, time_1_process = 0.0
# i=89,rest=26305, time_1_process = 0.0
# i=90,rest=26304, time_1_process = 0.015625
# i=91,rest=26303, time_1_process = 0.0
# i=92,rest=26302, time_1_process = 0.015625
# i=93,rest=26301, time_1_process = 0.0
# i=94,rest=26300, time_1_process = 0.015625
# i=95,rest=26299, time_1_process = 0.0
# i=96,rest=26298, time_1_process = 0.015625
# i=97,rest=26297, time_1_process = 0.0
# i=98,rest=26296, time_1_process = 0.015625
# i=99,rest=26295, time_1_process = 0.0
# i=100,rest=26294, time_1_process = 0.015625
# i=101,rest=26293, time_1_process = 0.0
# i=102,rest=26292, time_1_process = 0.0
# i=103,rest=26291, time_1_process = 0.015625
# i=104,rest=26290, time_1_process = 0.0
# i=105,rest=26289, time_1_process = 0.015625
# i=106,rest=26288, time_1_process = 0.0
# i=107,rest=26287, time_1_process = 0.015625
# i=108,rest=26286, time_1_process = 0.015625
# i=109,rest=26285, time_1_process = 0.0
# i=110,rest=26284, time_1_process = 0.015625
# i=111,rest=26283, time_1_process = 0.0
# i=112,rest=26282, time_1_process = 0.015625
# i=113,rest=26281, time_1_process = 0.0
# i=114,rest=26280, time_1_process = 0.0
# i=115,rest=26279, time_1_process = 0.03125
# i=116,rest=26278, time_1_process = 0.015625
# i=117,rest=26277, time_1_process = 0.0
# i=118,rest=26276, time_1_process = 0.015625
# i=119,rest=26275, time_1_process = 0.0
# i=120,rest=26274, time_1_process = 0.015625
# i=121,rest=26273, time_1_process = 0.0
# i=122,rest=26272, time_1_process = 0.015625
# i=123,rest=26271, time_1_process = 0.0
# i=124,rest=26270, time_1_process = 0.015625
# i=125,rest=26269, time_1_process = 0.0
# i=126,rest=26268, time_1_process = 0.015625
# i=127,rest=26267, time_1_process = 0.0
# i=128,rest=26266, time_1_process = 0.015625
# i=129,rest=26265, time_1_process = 0.0
# i=130,rest=26264, time_1_process = 0.015625
# i=131,rest=26263, time_1_process = 0.0
# i=132,rest=26262, time_1_process = 0.015625
# i=133,rest=26261, time_1_process = 0.015625
# i=134,rest=26260, time_1_process = 0.0
# i=135,rest=26259, time_1_process = 0.015625
# i=136,rest=26258, time_1_process = 0.0
# i=137,rest=26257, time_1_process = 0.015625
# i=138,rest=26256, time_1_process = 0.015625
# i=139,rest=26255, time_1_process = 0.0
# i=140,rest=26254, time_1_process = 0.015625
# i=141,rest=26253, time_1_process = 0.0
# i=142,rest=26252, time_1_process = 0.015625
# i=143,rest=26251, time_1_process = 0.0
# i=144,rest=26250, time_1_process = 0.015625
# i=145,rest=26249, time_1_process = 0.0
# i=146,rest=26248, time_1_process = 0.015625
# i=147,rest=26247, time_1_process = 0.0
# i=148,rest=26246, time_1_process = 0.015625
# i=149,rest=26245, time_1_process = 0.0
# i=150,rest=26244, time_1_process = 0.015625
# i=151,rest=26243, time_1_process = 0.0
# i=152,rest=26242, time_1_process = 0.015625
# i=153,rest=26241, time_1_process = 0.0
# i=154,rest=26240, time_1_process = 0.0
# i=155,rest=26239, time_1_process = 0.015625
# i=156,rest=26238, time_1_process = 0.0
# i=157,rest=26237, time_1_process = 0.015625
# i=158,rest=26236, time_1_process = 0.0
# i=159,rest=26235, time_1_process = 0.015625
# i=160,rest=26234, time_1_process = 0.0
# i=161,rest=26233, time_1_process = 0.015625
# i=162,rest=26232, time_1_process = 0.0
# i=163,rest=26231, time_1_process = 0.015625
# i=164,rest=26230, time_1_process = 0.0
# i=165,rest=26229, time_1_process = 0.015625
# i=166,rest=26228, time_1_process = 0.0
# i=167,rest=26227, time_1_process = 0.015625
# i=168,rest=26226, time_1_process = 0.0
# i=169,rest=26225, time_1_process = 0.015625
# i=170,rest=26224, time_1_process = 0.0
# i=171,rest=26223, time_1_process = 0.015625
# i=172,rest=26222, time_1_process = 0.0
# i=173,rest=26221, time_1_process = 0.015625
# i=174,rest=26220, time_1_process = 0.0
# i=175,rest=26219, time_1_process = 0.015625
# i=176,rest=26218, time_1_process = 0.0
# i=177,rest=26217, time_1_process = 0.015625
# i=178,rest=26216, time_1_process = 0.0
# i=179,rest=26215, time_1_process = 0.0
# i=180,rest=26214, time_1_process = 0.015625
# i=181,rest=26213, time_1_process = 0.015625
# i=182,rest=26212, time_1_process = 0.015625
# i=183,rest=26211, time_1_process = 0.0
# i=184,rest=26210, time_1_process = 0.015625
# i=185,rest=26209, time_1_process = 0.0
# i=186,rest=26208, time_1_process = 0.015625
# i=187,rest=26207, time_1_process = 0.0
# i=188,rest=26206, time_1_process = 0.015625
# i=189,rest=26205, time_1_process = 0.0
# i=190,rest=26204, time_1_process = 0.015625
# i=191,rest=26203, time_1_process = 0.015625
# i=192,rest=26202, time_1_process = 0.0
# i=193,rest=26201, time_1_process = 0.015625
# i=194,rest=26200, time_1_process = 0.0
# i=195,rest=26199, time_1_process = 0.015625
# i=196,rest=26198, time_1_process = 0.0
# i=197,rest=26197, time_1_process = 0.015625
# i=198,rest=26196, time_1_process = 0.0
# i=199,rest=26195, time_1_process = 0.015625
# i=200,rest=26194, time_1_process = 0.0
# i=201,rest=26193, time_1_process = 0.0
# i=202,rest=26192, time_1_process = 0.015625
# i=203,rest=26191, time_1_process = 0.0
# i=204,rest=26190, time_1_process = 0.015625
# i=205,rest=26189, time_1_process = 0.0
# i=206,rest=26188, time_1_process = 0.015625
# i=207,rest=26187, time_1_process = 0.0
# i=208,rest=26186, time_1_process = 0.015625
# i=209,rest=26185, time_1_process = 0.0
# i=210,rest=26184, time_1_process = 0.015625
# i=211,rest=26183, time_1_process = 0.0
# i=212,rest=26182, time_1_process = 0.015625
# i=213,rest=26181, time_1_process = 0.0
# i=214,rest=26180, time_1_process = 0.015625
# i=215,rest=26179, time_1_process = 0.0
# i=216,rest=26178, time_1_process = 0.015625
# i=217,rest=26177, time_1_process = 0.015625
# i=218,rest=26176, time_1_process = 0.0
# i=219,rest=26175, time_1_process = 0.015625
# i=220,rest=26174, time_1_process = 0.0
# i=221,rest=26173, time_1_process = 0.015625
# i=222,rest=26172, time_1_process = 0.0
# i=223,rest=26171, time_1_process = 0.015625
# i=224,rest=26170, time_1_process = 0.0
# i=225,rest=26169, time_1_process = 0.015625
# i=226,rest=26168, time_1_process = 0.015625
# i=227,rest=26167, time_1_process = 0.0
# i=228,rest=26166, time_1_process = 0.015625
# i=229,rest=26165, time_1_process = 0.0
# i=230,rest=26164, time_1_process = 0.015625
# i=231,rest=26163, time_1_process = 0.015625
# i=232,rest=26162, time_1_process = 0.0
# i=233,rest=26161, time_1_process = 0.015625
# i=234,rest=26160, time_1_process = 0.0
# i=235,rest=26159, time_1_process = 0.015625
# i=236,rest=26158, time_1_process = 0.0
# i=237,rest=26157, time_1_process = 0.015625
# i=238,rest=26156, time_1_process = 0.0
# i=239,rest=26155, time_1_process = 0.015625
# i=240,rest=26154, time_1_process = 0.0
# i=241,rest=26153, time_1_process = 0.015625
# i=242,rest=26152, time_1_process = 0.0
# i=243,rest=26151, time_1_process = 0.015625
# i=244,rest=26150, time_1_process = 0.0
# i=245,rest=26149, time_1_process = 0.0
# i=246,rest=26148, time_1_process = 0.015625
# i=247,rest=26147, time_1_process = 0.0
# i=248,rest=26146, time_1_process = 0.015625
# i=249,rest=26145, time_1_process = 0.015625
# i=250,rest=26144, time_1_process = 0.0
# i=251,rest=26143, time_1_process = 0.015625
# i=252,rest=26142, time_1_process = 0.0
# i=253,rest=26141, time_1_process = 0.015625
# i=254,rest=26140, time_1_process = 0.0
# i=255,rest=26139, time_1_process = 0.0
# i=256,rest=26138, time_1_process = 0.015625
# i=257,rest=26137, time_1_process = 0.0
# i=258,rest=26136, time_1_process = 0.015625
# i=259,rest=26135, time_1_process = 0.015625
# i=260,rest=26134, time_1_process = 0.0
# i=261,rest=26133, time_1_process = 0.015625
# i=262,rest=26132, time_1_process = 0.0
# i=263,rest=26131, time_1_process = 0.015625
# i=264,rest=26130, time_1_process = 0.015625
# i=265,rest=26129, time_1_process = 0.0
# i=266,rest=26128, time_1_process = 0.015625
# i=267,rest=26127, time_1_process = 0.0
# i=268,rest=26126, time_1_process = 0.0
# i=269,rest=26125, time_1_process = 0.015625
# i=270,rest=26124, time_1_process = 0.0
# i=271,rest=26123, time_1_process = 0.015625
# i=272,rest=26122, time_1_process = 0.0
# i=273,rest=26121, time_1_process = 0.015625
# i=274,rest=26120, time_1_process = 0.0
# i=275,rest=26119, time_1_process = 0.015625
# i=276,rest=26118, time_1_process = 0.0
# i=277,rest=26117, time_1_process = 0.015625
# i=278,rest=26116, time_1_process = 0.015625
# i=279,rest=26115, time_1_process = 0.0
# i=280,rest=26114, time_1_process = 0.015625
# i=281,rest=26113, time_1_process = 0.0
# i=282,rest=26112, time_1_process = 0.015625
# i=283,rest=26111, time_1_process = 0.0
# i=284,rest=26110, time_1_process = 0.015625
# i=285,rest=26109, time_1_process = 0.0
# i=286,rest=26108, time_1_process = 0.0
# i=287,rest=26107, time_1_process = 0.015625
# i=288,rest=26106, time_1_process = 0.0
# i=289,rest=26105, time_1_process = 0.015625
# i=290,rest=26104, time_1_process = 0.0
# i=291,rest=26103, time_1_process = 0.015625
# i=292,rest=26102, time_1_process = 0.0
# i=293,rest=26101, time_1_process = 0.015625
# i=294,rest=26100, time_1_process = 0.0
# i=295,rest=26099, time_1_process = 0.015625
# i=296,rest=26098, time_1_process = 0.015625
# i=297,rest=26097, time_1_process = 0.0
# i=298,rest=26096, time_1_process = 0.015625
# i=299,rest=26095, time_1_process = 0.0
# i=300,rest=26094, time_1_process = 0.015625
# i=301,rest=26093, time_1_process = 0.0
# i=302,rest=26092, time_1_process = 0.015625
# i=303,rest=26091, time_1_process = 0.0
# i=304,rest=26090, time_1_process = 0.015625
# i=305,rest=26089, time_1_process = 0.0
# i=306,rest=26088, time_1_process = 0.015625
# i=307,rest=26087, time_1_process = 0.0
# i=308,rest=26086, time_1_process = 0.015625
# i=309,rest=26085, time_1_process = 0.0
# i=310,rest=26084, time_1_process = 0.015625
# i=311,rest=26083, time_1_process = 0.0
# i=312,rest=26082, time_1_process = 0.0
# i=313,rest=26081, time_1_process = 0.015625
# i=314,rest=26080, time_1_process = 0.0
# i=315,rest=26079, time_1_process = 0.015625
# i=316,rest=26078, time_1_process = 0.0
# i=317,rest=26077, time_1_process = 0.015625
# i=318,rest=26076, time_1_process = 0.0
# i=319,rest=26075, time_1_process = 0.015625
# i=320,rest=26074, time_1_process = 0.0
# i=321,rest=26073, time_1_process = 0.015625
# i=322,rest=26072, time_1_process = 0.0
# i=323,rest=26071, time_1_process = 0.015625
# i=324,rest=26070, time_1_process = 0.0
# i=325,rest=26069, time_1_process = 0.015625
# i=326,rest=26068, time_1_process = 0.0
# i=327,rest=26067, time_1_process = 0.0
# i=328,rest=26066, time_1_process = 0.015625
# i=329,rest=26065, time_1_process = 0.0
# i=330,rest=26064, time_1_process = 0.015625
# i=331,rest=26063, time_1_process = 0.015625
# i=332,rest=26062, time_1_process = 0.0
# i=333,rest=26061, time_1_process = 0.015625
# i=334,rest=26060, time_1_process = 0.015625
# i=335,rest=26059, time_1_process = 0.0
# i=336,rest=26058, time_1_process = 0.015625
# i=337,rest=26057, time_1_process = 0.0
# i=338,rest=26056, time_1_process = 0.0
# i=339,rest=26055, time_1_process = 0.015625
# i=340,rest=26054, time_1_process = 0.0
# i=341,rest=26053, time_1_process = 0.015625
# i=342,rest=26052, time_1_process = 0.0
# i=343,rest=26051, time_1_process = 0.015625
# i=344,rest=26050, time_1_process = 0.0
# i=345,rest=26049, time_1_process = 0.015625
# i=346,rest=26048, time_1_process = 0.0
# i=347,rest=26047, time_1_process = 0.015625
# i=348,rest=26046, time_1_process = 0.0
# i=349,rest=26045, time_1_process = 0.015625
# i=350,rest=26044, time_1_process = 0.0
# i=351,rest=26043, time_1_process = 0.015625
# i=352,rest=26042, time_1_process = 0.0
# i=353,rest=26041, time_1_process = 0.015625
# i=354,rest=26040, time_1_process = 0.0
# i=355,rest=26039, time_1_process = 0.0
# i=356,rest=26038, time_1_process = 0.015625
# i=357,rest=26037, time_1_process = 0.0
# i=358,rest=26036, time_1_process = 0.015625
# i=359,rest=26035, time_1_process = 0.0
# i=360,rest=26034, time_1_process = 0.015625
# i=361,rest=26033, time_1_process = 0.0
# i=362,rest=26032, time_1_process = 0.015625
# i=363,rest=26031, time_1_process = 0.0
# i=364,rest=26030, time_1_process = 0.015625
# i=365,rest=26029, time_1_process = 0.0
# i=366,rest=26028, time_1_process = 0.015625
# i=367,rest=26027, time_1_process = 0.0
# i=368,rest=26026, time_1_process = 0.015625
# i=369,rest=26025, time_1_process = 0.0
# i=370,rest=26024, time_1_process = 0.015625
# i=371,rest=26023, time_1_process = 0.0
# i=372,rest=26022, time_1_process = 0.015625
# i=373,rest=26021, time_1_process = 0.0
# i=374,rest=26020, time_1_process = 0.015625
# i=375,rest=26019, time_1_process = 0.0
# i=376,rest=26018, time_1_process = 0.015625
# i=377,rest=26017, time_1_process = 0.015625
# i=378,rest=26016, time_1_process = 0.0
# i=379,rest=26015, time_1_process = 0.0
# i=380,rest=26014, time_1_process = 0.015625
# i=381,rest=26013, time_1_process = 0.0
# i=382,rest=26012, time_1_process = 0.015625
# i=383,rest=26011, time_1_process = 0.0
# i=384,rest=26010, time_1_process = 0.015625
# i=385,rest=26009, time_1_process = 0.0
# i=386,rest=26008, time_1_process = 0.015625
# i=387,rest=26007, time_1_process = 0.0
# i=388,rest=26006, time_1_process = 0.015625
# i=389,rest=26005, time_1_process = 0.0
# i=390,rest=26004, time_1_process = 0.015625
# i=391,rest=26003, time_1_process = 0.0
# i=392,rest=26002, time_1_process = 0.015625
# i=393,rest=26001, time_1_process = 0.0
# i=394,rest=26000, time_1_process = 0.015625
# i=395,rest=25999, time_1_process = 0.0
# i=396,rest=25998, time_1_process = 0.0
# i=397,rest=25997, time_1_process = 0.015625
# i=398,rest=25996, time_1_process = 0.0
# i=399,rest=25995, time_1_process = 0.015625
# i=400,rest=25994, time_1_process = 0.0
# i=401,rest=25993, time_1_process = 0.015625
# i=402,rest=25992, time_1_process = 0.0
# i=403,rest=25991, time_1_process = 0.015625
# i=404,rest=25990, time_1_process = 0.0
# i=405,rest=25989, time_1_process = 0.015625
# i=406,rest=25988, time_1_process = 0.0
# i=407,rest=25987, time_1_process = 0.015625
# i=408,rest=25986, time_1_process = 0.0
# i=409,rest=25985, time_1_process = 0.0
# i=410,rest=25984, time_1_process = 0.015625
# i=411,rest=25983, time_1_process = 0.015625
# i=412,rest=25982, time_1_process = 0.0
# i=413,rest=25981, time_1_process = 0.015625
# i=414,rest=25980, time_1_process = 0.0
# i=415,rest=25979, time_1_process = 0.015625
# i=416,rest=25978, time_1_process = 0.0
# i=417,rest=25977, time_1_process = 0.015625
# i=418,rest=25976, time_1_process = 0.015625
# i=419,rest=25975, time_1_process = 0.015625
# i=420,rest=25974, time_1_process = 0.0
# i=421,rest=25973, time_1_process = 0.0
# i=422,rest=25972, time_1_process = 0.015625
# i=423,rest=25971, time_1_process = 0.0
# i=424,rest=25970, time_1_process = 0.015625
# i=425,rest=25969, time_1_process = 0.0
# i=426,rest=25968, time_1_process = 0.015625
# i=427,rest=25967, time_1_process = 0.0
# i=428,rest=25966, time_1_process = 0.015625
# i=429,rest=25965, time_1_process = 0.0
# i=430,rest=25964, time_1_process = 0.015625
# i=431,rest=25963, time_1_process = 0.0
# i=432,rest=25962, time_1_process = 0.015625
# i=433,rest=25961, time_1_process = 0.0
# i=434,rest=25960, time_1_process = 0.015625
# i=435,rest=25959, time_1_process = 0.0
# i=436,rest=25958, time_1_process = 0.015625
# i=437,rest=25957, time_1_process = 0.0
# i=438,rest=25956, time_1_process = 0.015625
# i=439,rest=25955, time_1_process = 0.0
# i=440,rest=25954, time_1_process = 0.015625
# i=441,rest=25953, time_1_process = 0.0
# i=442,rest=25952, time_1_process = 0.015625
# i=443,rest=25951, time_1_process = 0.0
# i=444,rest=25950, time_1_process = 0.015625
# i=445,rest=25949, time_1_process = 0.0
# i=446,rest=25948, time_1_process = 0.015625
# i=447,rest=25947, time_1_process = 0.0
# i=448,rest=25946, time_1_process = 0.015625
# i=449,rest=25945, time_1_process = 0.0
# i=450,rest=25944, time_1_process = 0.0
# i=451,rest=25943, time_1_process = 0.015625
# i=452,rest=25942, time_1_process = 0.0
# i=453,rest=25941, time_1_process = 0.015625
# i=454,rest=25940, time_1_process = 0.0
# i=455,rest=25939, time_1_process = 0.015625
# i=456,rest=25938, time_1_process = 0.0
# i=457,rest=25937, time_1_process = 0.015625
# i=458,rest=25936, time_1_process = 0.0
# i=459,rest=25935, time_1_process = 0.0
# i=460,rest=25934, time_1_process = 0.015625
# i=461,rest=25933, time_1_process = 0.0
# i=462,rest=25932, time_1_process = 0.015625
# i=463,rest=25931, time_1_process = 0.0
# i=464,rest=25930, time_1_process = 0.015625
# i=465,rest=25929, time_1_process = 0.0
# i=466,rest=25928, time_1_process = 0.015625
# i=467,rest=25927, time_1_process = 0.0
# i=468,rest=25926, time_1_process = 0.0
# i=469,rest=25925, time_1_process = 0.015625
# i=470,rest=25924, time_1_process = 0.0
# i=471,rest=25923, time_1_process = 0.015625
# i=472,rest=25922, time_1_process = 0.0
# i=473,rest=25921, time_1_process = 0.015625
# i=474,rest=25920, time_1_process = 0.0
# i=475,rest=25919, time_1_process = 0.015625
# i=476,rest=25918, time_1_process = 0.0
# i=477,rest=25917, time_1_process = 0.015625
# i=478,rest=25916, time_1_process = 0.0
# i=479,rest=25915, time_1_process = 0.015625
# i=480,rest=25914, time_1_process = 0.0
# i=481,rest=25913, time_1_process = 0.0
# i=482,rest=25912, time_1_process = 0.015625
# i=483,rest=25911, time_1_process = 0.0
# i=484,rest=25910, time_1_process = 0.015625
# i=485,rest=25909, time_1_process = 0.0
# i=486,rest=25908, time_1_process = 0.015625
# i=487,rest=25907, time_1_process = 0.0
# i=488,rest=25906, time_1_process = 0.015625
# i=489,rest=25905, time_1_process = 0.0
# i=490,rest=25904, time_1_process = 0.015625
# i=491,rest=25903, time_1_process = 0.0
# i=492,rest=25902, time_1_process = 0.015625
# i=493,rest=25901, time_1_process = 0.0
# i=494,rest=25900, time_1_process = 0.0
# i=495,rest=25899, time_1_process = 0.015625
# i=496,rest=25898, time_1_process = 0.0
# i=497,rest=25897, time_1_process = 0.015625
# i=498,rest=25896, time_1_process = 0.0
# i=499,rest=25895, time_1_process = 0.015625
# i=500,rest=25894, time_1_process = 0.0
# i=501,rest=25893, time_1_process = 0.015625
# i=502,rest=25892, time_1_process = 0.0
# i=503,rest=25891, time_1_process = 0.0
# i=504,rest=25890, time_1_process = 0.015625
# i=505,rest=25889, time_1_process = 0.0
# i=506,rest=25888, time_1_process = 0.015625
# i=507,rest=25887, time_1_process = 0.0
# i=508,rest=25886, time_1_process = 0.015625
# i=509,rest=25885, time_1_process = 0.0
# i=510,rest=25884, time_1_process = 0.015625
# i=511,rest=25883, time_1_process = 0.0
# i=512,rest=25882, time_1_process = 0.015625
# i=513,rest=25881, time_1_process = 0.0
# i=514,rest=25880, time_1_process = 0.0
# i=515,rest=25879, time_1_process = 0.015625
# i=516,rest=25878, time_1_process = 0.0
# i=517,rest=25877, time_1_process = 0.015625
# i=518,rest=25876, time_1_process = 0.0
# i=519,rest=25875, time_1_process = 0.015625
# i=520,rest=25874, time_1_process = 0.0
# i=521,rest=25873, time_1_process = 0.015625
# i=522,rest=25872, time_1_process = 0.0
# i=523,rest=25871, time_1_process = 0.015625
# i=524,rest=25870, time_1_process = 0.0
# i=525,rest=25869, time_1_process = 0.0
# i=526,rest=25868, time_1_process = 0.015625
# i=527,rest=25867, time_1_process = 0.0
# i=528,rest=25866, time_1_process = 0.015625
# i=529,rest=25865, time_1_process = 0.0
# i=530,rest=25864, time_1_process = 0.015625
# i=531,rest=25863, time_1_process = 0.0
# i=532,rest=25862, time_1_process = 0.015625
# i=533,rest=25861, time_1_process = 0.0
# i=534,rest=25860, time_1_process = 0.015625
# i=535,rest=25859, time_1_process = 0.0
# i=536,rest=25858, time_1_process = 0.015625
# i=537,rest=25857, time_1_process = 0.0
# i=538,rest=25856, time_1_process = 0.0
# i=539,rest=25855, time_1_process = 0.015625
# i=540,rest=25854, time_1_process = 0.0
# i=541,rest=25853, time_1_process = 0.015625
# i=542,rest=25852, time_1_process = 0.0
# i=543,rest=25851, time_1_process = 0.015625
# i=544,rest=25850, time_1_process = 0.0
# i=545,rest=25849, time_1_process = 0.0
# i=546,rest=25848, time_1_process = 0.015625
# i=547,rest=25847, time_1_process = 0.0
# i=548,rest=25846, time_1_process = 0.015625
# i=549,rest=25845, time_1_process = 0.0
# i=550,rest=25844, time_1_process = 0.015625
# i=551,rest=25843, time_1_process = 0.0
# i=552,rest=25842, time_1_process = 0.015625
# i=553,rest=25841, time_1_process = 0.0
# i=554,rest=25840, time_1_process = 0.015625
# i=555,rest=25839, time_1_process = 0.0
# i=556,rest=25838, time_1_process = 0.015625
# i=557,rest=25837, time_1_process = 0.0
# i=558,rest=25836, time_1_process = 0.015625
# i=559,rest=25835, time_1_process = 0.0
# i=560,rest=25834, time_1_process = 0.015625
# i=561,rest=25833, time_1_process = 0.0
# i=562,rest=25832, time_1_process = 0.015625
# i=563,rest=25831, time_1_process = 0.0
# i=564,rest=25830, time_1_process = 0.015625
# i=565,rest=25829, time_1_process = 0.0
# i=566,rest=25828, time_1_process = 0.015625
# i=567,rest=25827, time_1_process = 0.0
# i=568,rest=25826, time_1_process = 0.015625
# i=569,rest=25825, time_1_process = 0.0
# i=570,rest=25824, time_1_process = 0.0
# i=571,rest=25823, time_1_process = 0.015625
# i=572,rest=25822, time_1_process = 0.0
# i=573,rest=25821, time_1_process = 0.015625
# i=574,rest=25820, time_1_process = 0.0
# i=575,rest=25819, time_1_process = 0.015625
# i=576,rest=25818, time_1_process = 0.0
# i=577,rest=25817, time_1_process = 0.015625
# i=578,rest=25816, time_1_process = 0.0
# i=579,rest=25815, time_1_process = 0.015625
# i=580,rest=25814, time_1_process = 0.0
# i=581,rest=25813, time_1_process = 0.0
# i=582,rest=25812, time_1_process = 0.015625
# i=583,rest=25811, time_1_process = 0.0
# i=584,rest=25810, time_1_process = 0.015625
# i=585,rest=25809, time_1_process = 0.0
# i=586,rest=25808, time_1_process = 0.015625
# i=587,rest=25807, time_1_process = 0.0
# i=588,rest=25806, time_1_process = 0.015625
# i=589,rest=25805, time_1_process = 0.0
# i=590,rest=25804, time_1_process = 0.0
# i=591,rest=25803, time_1_process = 0.015625
# i=592,rest=25802, time_1_process = 0.0
# i=593,rest=25801, time_1_process = 0.015625
# i=594,rest=25800, time_1_process = 0.0
# i=595,rest=25799, time_1_process = 0.015625
# i=596,rest=25798, time_1_process = 0.0
# i=597,rest=25797, time_1_process = 0.015625
# i=598,rest=25796, time_1_process = 0.0
# i=599,rest=25795, time_1_process = 0.015625
# i=600,rest=25794, time_1_process = 0.0
# i=601,rest=25793, time_1_process = 0.0
# i=602,rest=25792, time_1_process = 0.015625
# i=603,rest=25791, time_1_process = 0.0
# i=604,rest=25790, time_1_process = 0.015625
# i=605,rest=25789, time_1_process = 0.0
# i=606,rest=25788, time_1_process = 0.015625
# i=607,rest=25787, time_1_process = 0.0
# i=608,rest=25786, time_1_process = 0.015625
# i=609,rest=25785, time_1_process = 0.0
# i=610,rest=25784, time_1_process = 0.0
# i=611,rest=25783, time_1_process = 0.015625
# i=612,rest=25782, time_1_process = 0.0
# i=613,rest=25781, time_1_process = 0.015625
# i=614,rest=25780, time_1_process = 0.0
# i=615,rest=25779, time_1_process = 0.015625
# i=616,rest=25778, time_1_process = 0.0
# i=617,rest=25777, time_1_process = 0.015625
# i=618,rest=25776, time_1_process = 0.0
# i=619,rest=25775, time_1_process = 0.015625
# i=620,rest=25774, time_1_process = 0.0
# i=621,rest=25773, time_1_process = 0.015625
# i=622,rest=25772, time_1_process = 0.0
# i=623,rest=25771, time_1_process = 0.0
# i=624,rest=25770, time_1_process = 0.015625
# i=625,rest=25769, time_1_process = 0.0
# i=626,rest=25768, time_1_process = 0.015625
# i=627,rest=25767, time_1_process = 0.0
# i=628,rest=25766, time_1_process = 0.015625
# i=629,rest=25765, time_1_process = 0.0
# i=630,rest=25764, time_1_process = 0.015625
# i=631,rest=25763, time_1_process = 0.0
# i=632,rest=25762, time_1_process = 0.015625
# i=633,rest=25761, time_1_process = 0.0
# i=634,rest=25760, time_1_process = 0.0
# i=635,rest=25759, time_1_process = 0.015625
# i=636,rest=25758, time_1_process = 0.0
# i=637,rest=25757, time_1_process = 0.015625
# i=638,rest=25756, time_1_process = 0.0
# i=639,rest=25755, time_1_process = 0.015625
# i=640,rest=25754, time_1_process = 0.0
# i=641,rest=25753, time_1_process = 0.015625
# i=642,rest=25752, time_1_process = 0.0
# i=643,rest=25751, time_1_process = 0.015625
# i=644,rest=25750, time_1_process = 0.0
# i=645,rest=25749, time_1_process = 0.0
# i=646,rest=25748, time_1_process = 0.015625
# i=647,rest=25747, time_1_process = 0.0
# i=648,rest=25746, time_1_process = 0.015625
# i=649,rest=25745, time_1_process = 0.0
# i=650,rest=25744, time_1_process = 0.015625
# i=651,rest=25743, time_1_process = 0.0
# i=652,rest=25742, time_1_process = 0.015625
# i=653,rest=25741, time_1_process = 0.0
# i=654,rest=25740, time_1_process = 0.015625
# i=655,rest=25739, time_1_process = 0.0
# i=656,rest=25738, time_1_process = 0.015625
# i=657,rest=25737, time_1_process = 0.0
# i=658,rest=25736, time_1_process = 0.0
# i=659,rest=25735, time_1_process = 0.015625
# i=660,rest=25734, time_1_process = 0.0
# i=661,rest=25733, time_1_process = 0.015625
# i=662,rest=25732, time_1_process = 0.0
# i=663,rest=25731, time_1_process = 0.015625
# i=664,rest=25730, time_1_process = 0.0
# i=665,rest=25729, time_1_process = 0.0
# i=666,rest=25728, time_1_process = 0.015625
# i=667,rest=25727, time_1_process = 0.0
# i=668,rest=25726, time_1_process = 0.015625
# i=669,rest=25725, time_1_process = 0.0
# i=670,rest=25724, time_1_process = 0.015625
# i=671,rest=25723, time_1_process = 0.0
# i=672,rest=25722, time_1_process = 0.015625
# i=673,rest=25721, time_1_process = 0.0
# i=674,rest=25720, time_1_process = 0.015625
# i=675,rest=25719, time_1_process = 0.0
# i=676,rest=25718, time_1_process = 0.0
# i=677,rest=25717, time_1_process = 0.015625
# i=678,rest=25716, time_1_process = 0.0
# i=679,rest=25715, time_1_process = 0.015625
# i=680,rest=25714, time_1_process = 0.0
# i=681,rest=25713, time_1_process = 0.015625
# i=682,rest=25712, time_1_process = 0.0
# i=683,rest=25711, time_1_process = 0.015625
# i=684,rest=25710, time_1_process = 0.0
# i=685,rest=25709, time_1_process = 0.015625
# i=686,rest=25708, time_1_process = 0.0
# i=687,rest=25707, time_1_process = 0.015625
# i=688,rest=25706, time_1_process = 0.0
# i=689,rest=25705, time_1_process = 0.0
# i=690,rest=25704, time_1_process = 0.015625
# i=691,rest=25703, time_1_process = 0.0
# i=692,rest=25702, time_1_process = 0.015625
# i=693,rest=25701, time_1_process = 0.0
# i=694,rest=25700, time_1_process = 0.015625
# i=695,rest=25699, time_1_process = 0.0
# i=696,rest=25698, time_1_process = 0.015625
# i=697,rest=25697, time_1_process = 0.0
# i=698,rest=25696, time_1_process = 0.015625
# i=699,rest=25695, time_1_process = 0.0
# i=700,rest=25694, time_1_process = 0.015625
# i=701,rest=25693, time_1_process = 0.0
# i=702,rest=25692, time_1_process = 0.0
# i=703,rest=25691, time_1_process = 0.015625
# i=704,rest=25690, time_1_process = 0.0
# i=705,rest=25689, time_1_process = 0.015625
# i=706,rest=25688, time_1_process = 0.0
# i=707,rest=25687, time_1_process = 0.015625
# i=708,rest=25686, time_1_process = 0.0
# i=709,rest=25685, time_1_process = 0.03125
# i=710,rest=25684, time_1_process = 0.0
# i=711,rest=25683, time_1_process = 0.015625
# i=712,rest=25682, time_1_process = 0.0
# i=713,rest=25681, time_1_process = 0.0
# i=714,rest=25680, time_1_process = 0.015625
# i=715,rest=25679, time_1_process = 0.0
# i=716,rest=25678, time_1_process = 0.015625
# i=717,rest=25677, time_1_process = 0.0
# i=718,rest=25676, time_1_process = 0.015625
# i=719,rest=25675, time_1_process = 0.0
# i=720,rest=25674, time_1_process = 0.015625
# i=721,rest=25673, time_1_process = 0.0
# i=722,rest=25672, time_1_process = 0.0
# i=723,rest=25671, time_1_process = 0.015625
# i=724,rest=25670, time_1_process = 0.0
# i=725,rest=25669, time_1_process = 0.015625
# i=726,rest=25668, time_1_process = 0.0
# i=727,rest=25667, time_1_process = 0.015625
# i=728,rest=25666, time_1_process = 0.0
# i=729,rest=25665, time_1_process = 0.015625
# i=730,rest=25664, time_1_process = 0.0
# i=731,rest=25663, time_1_process = 0.015625
# i=732,rest=25662, time_1_process = 0.0
# i=733,rest=25661, time_1_process = 0.0
# i=734,rest=25660, time_1_process = 0.015625
# i=735,rest=25659, time_1_process = 0.0
# i=736,rest=25658, time_1_process = 0.015625
# i=737,rest=25657, time_1_process = 0.0
# i=738,rest=25656, time_1_process = 0.015625
# i=739,rest=25655, time_1_process = 0.0
# i=740,rest=25654, time_1_process = 0.015625
# i=741,rest=25653, time_1_process = 0.0
# i=742,rest=25652, time_1_process = 0.015625
# i=743,rest=25651, time_1_process = 0.0
# i=744,rest=25650, time_1_process = 0.015625
# i=745,rest=25649, time_1_process = 0.0
# i=746,rest=25648, time_1_process = 0.0
# i=747,rest=25647, time_1_process = 0.015625
# i=748,rest=25646, time_1_process = 0.0
# i=749,rest=25645, time_1_process = 0.015625
# i=750,rest=25644, time_1_process = 0.0
# i=751,rest=25643, time_1_process = 0.015625
# i=752,rest=25642, time_1_process = 0.0
# i=753,rest=25641, time_1_process = 0.015625
# i=754,rest=25640, time_1_process = 0.0
# i=755,rest=25639, time_1_process = 0.015625
# i=756,rest=25638, time_1_process = 0.0
# i=757,rest=25637, time_1_process = 0.0
# i=758,rest=25636, time_1_process = 0.015625
# i=759,rest=25635, time_1_process = 0.0
# i=760,rest=25634, time_1_process = 0.015625
# i=761,rest=25633, time_1_process = 0.0
# i=762,rest=25632, time_1_process = 0.015625
# i=763,rest=25631, time_1_process = 0.0
# i=764,rest=25630, time_1_process = 0.0
# i=765,rest=25629, time_1_process = 0.015625
# i=766,rest=25628, time_1_process = 0.0
# i=767,rest=25627, time_1_process = 0.015625
# i=768,rest=25626, time_1_process = 0.0
# i=769,rest=25625, time_1_process = 0.015625
# i=770,rest=25624, time_1_process = 0.0
# i=771,rest=25623, time_1_process = 0.015625
# i=772,rest=25622, time_1_process = 0.0
# i=773,rest=25621, time_1_process = 0.015625
# i=774,rest=25620, time_1_process = 0.0
# i=775,rest=25619, time_1_process = 0.015625
# i=776,rest=25618, time_1_process = 0.0
# i=777,rest=25617, time_1_process = 0.0
# i=778,rest=25616, time_1_process = 0.015625
# i=779,rest=25615, time_1_process = 0.0
# i=780,rest=25614, time_1_process = 0.015625
# i=781,rest=25613, time_1_process = 0.0
# i=782,rest=25612, time_1_process = 0.015625
# i=783,rest=25611, time_1_process = 0.0
# i=784,rest=25610, time_1_process = 0.015625
# i=785,rest=25609, time_1_process = 0.0
# i=786,rest=25608, time_1_process = 0.015625
# i=787,rest=25607, time_1_process = 0.0
# i=788,rest=25606, time_1_process = 0.015625
# i=789,rest=25605, time_1_process = 0.0
# i=790,rest=25604, time_1_process = 0.015625
# i=791,rest=25603, time_1_process = 0.0
# i=792,rest=25602, time_1_process = 0.0
# i=793,rest=25601, time_1_process = 0.015625
# i=794,rest=25600, time_1_process = 0.0
# i=795,rest=25599, time_1_process = 0.015625
# i=796,rest=25598, time_1_process = 0.0
# i=797,rest=25597, time_1_process = 0.015625
# i=798,rest=25596, time_1_process = 0.0
# i=799,rest=25595, time_1_process = 0.015625
# i=800,rest=25594, time_1_process = 0.0
# i=801,rest=25593, time_1_process = 0.015625
# i=802,rest=25592, time_1_process = 0.0
# i=803,rest=25591, time_1_process = 0.015625
# i=804,rest=25590, time_1_process = 0.0
# i=805,rest=25589, time_1_process = 0.015625
# i=806,rest=25588, time_1_process = 0.0
# i=807,rest=25587, time_1_process = 0.0
# i=808,rest=25586, time_1_process = 0.015625
# i=809,rest=25585, time_1_process = 0.0
# i=810,rest=25584, time_1_process = 0.015625
# i=811,rest=25583, time_1_process = 0.0
# i=812,rest=25582, time_1_process = 0.015625
# i=813,rest=25581, time_1_process = 0.0
# i=814,rest=25580, time_1_process = 0.015625
# i=815,rest=25579, time_1_process = 0.0
# i=816,rest=25578, time_1_process = 0.015625
# i=817,rest=25577, time_1_process = 0.0
# i=818,rest=25576, time_1_process = 0.0
# i=819,rest=25575, time_1_process = 0.015625
# i=820,rest=25574, time_1_process = 0.0
# i=821,rest=25573, time_1_process = 0.015625
# i=822,rest=25572, time_1_process = 0.0
# i=823,rest=25571, time_1_process = 0.015625
# i=824,rest=25570, time_1_process = 0.0
# i=825,rest=25569, time_1_process = 0.015625
# i=826,rest=25568, time_1_process = 0.0
# i=827,rest=25567, time_1_process = 0.0
# i=828,rest=25566, time_1_process = 0.015625
# i=829,rest=25565, time_1_process = 0.0
# i=830,rest=25564, time_1_process = 0.015625
# i=831,rest=25563, time_1_process = 0.0
# i=832,rest=25562, time_1_process = 0.015625
# i=833,rest=25561, time_1_process = 0.0
# i=834,rest=25560, time_1_process = 0.015625
# i=835,rest=25559, time_1_process = 0.0
# i=836,rest=25558, time_1_process = 0.015625
# i=837,rest=25557, time_1_process = 0.0
# i=838,rest=25556, time_1_process = 0.015625
# i=839,rest=25555, time_1_process = 0.0
# i=840,rest=25554, time_1_process = 0.015625
# i=841,rest=25553, time_1_process = 0.0
# i=842,rest=25552, time_1_process = 0.0
# i=843,rest=25551, time_1_process = 0.015625
# i=844,rest=25550, time_1_process = 0.0
# i=845,rest=25549, time_1_process = 0.015625
# i=846,rest=25548, time_1_process = 0.0
# i=847,rest=25547, time_1_process = 0.015625
# i=848,rest=25546, time_1_process = 0.0
# i=849,rest=25545, time_1_process = 0.015625
# i=850,rest=25544, time_1_process = 0.0
# i=851,rest=25543, time_1_process = 0.015625
# i=852,rest=25542, time_1_process = 0.0
# i=853,rest=25541, time_1_process = 0.015625
# i=854,rest=25540, time_1_process = 0.0
# i=855,rest=25539, time_1_process = 0.015625
# i=856,rest=25538, time_1_process = 0.0
# i=857,rest=25537, time_1_process = 0.015625
# i=858,rest=25536, time_1_process = 0.0
# i=859,rest=25535, time_1_process = 0.015625
# i=860,rest=25534, time_1_process = 0.0
# i=861,rest=25533, time_1_process = 0.015625
# i=862,rest=25532, time_1_process = 0.0
# i=863,rest=25531, time_1_process = 0.0
# i=864,rest=25530, time_1_process = 0.015625
# i=865,rest=25529, time_1_process = 0.0
# i=866,rest=25528, time_1_process = 0.015625
# i=867,rest=25527, time_1_process = 0.0
# i=868,rest=25526, time_1_process = 0.015625
# i=869,rest=25525, time_1_process = 0.0
# i=870,rest=25524, time_1_process = 0.0
# i=871,rest=25523, time_1_process = 0.0
# i=872,rest=25522, time_1_process = 0.0
# i=873,rest=25521, time_1_process = 0.015625
# i=874,rest=25520, time_1_process = 0.0
# i=875,rest=25519, time_1_process = 0.015625
# i=876,rest=25518, time_1_process = 0.0
# i=877,rest=25517, time_1_process = 0.015625
# i=878,rest=25516, time_1_process = 0.0
# i=879,rest=25515, time_1_process = 0.0
# i=880,rest=25514, time_1_process = 0.015625
# i=881,rest=25513, time_1_process = 0.0
# i=882,rest=25512, time_1_process = 0.015625
# i=883,rest=25511, time_1_process = 0.0
# i=884,rest=25510, time_1_process = 0.015625
# i=885,rest=25509, time_1_process = 0.0
# i=886,rest=25508, time_1_process = 0.015625
# i=887,rest=25507, time_1_process = 0.0
# i=888,rest=25506, time_1_process = 0.015625
# i=889,rest=25505, time_1_process = 0.0
# i=890,rest=25504, time_1_process = 0.015625
# i=891,rest=25503, time_1_process = 0.0
# i=892,rest=25502, time_1_process = 0.015625
# i=893,rest=25501, time_1_process = 0.0
# i=894,rest=25500, time_1_process = 0.015625
# i=895,rest=25499, time_1_process = 0.0
# i=896,rest=25498, time_1_process = 0.0
# i=897,rest=25497, time_1_process = 0.015625
# i=898,rest=25496, time_1_process = 0.0
# i=899,rest=25495, time_1_process = 0.015625
# i=900,rest=25494, time_1_process = 0.0
# i=901,rest=25493, time_1_process = 0.015625
# i=902,rest=25492, time_1_process = 0.0
# i=903,rest=25491, time_1_process = 0.0
# i=904,rest=25490, time_1_process = 0.015625
# i=905,rest=25489, time_1_process = 0.0
# i=906,rest=25488, time_1_process = 0.015625
# i=907,rest=25487, time_1_process = 0.0
# i=908,rest=25486, time_1_process = 0.015625
# i=909,rest=25485, time_1_process = 0.0
# i=910,rest=25484, time_1_process = 0.015625
# i=911,rest=25483, time_1_process = 0.0
# i=912,rest=25482, time_1_process = 0.015625
# i=913,rest=25481, time_1_process = 0.0
# i=914,rest=25480, time_1_process = 0.0
# i=915,rest=25479, time_1_process = 0.015625
# i=916,rest=25478, time_1_process = 0.0
# i=917,rest=25477, time_1_process = 0.015625
# i=918,rest=25476, time_1_process = 0.0
# i=919,rest=25475, time_1_process = 0.015625
# i=920,rest=25474, time_1_process = 0.0
# i=921,rest=25473, time_1_process = 0.015625
# i=922,rest=25472, time_1_process = 0.0
# i=923,rest=25471, time_1_process = 0.015625
# i=924,rest=25470, time_1_process = 0.0
# i=925,rest=25469, time_1_process = 0.015625
# i=926,rest=25468, time_1_process = 0.0
# i=927,rest=25467, time_1_process = 0.0
# i=928,rest=25466, time_1_process = 0.015625
# i=929,rest=25465, time_1_process = 0.0
# i=930,rest=25464, time_1_process = 0.015625
# i=931,rest=25463, time_1_process = 0.0
# i=932,rest=25462, time_1_process = 0.015625
# i=933,rest=25461, time_1_process = 0.015625
# i=934,rest=25460, time_1_process = 0.0
# i=935,rest=25459, time_1_process = 0.015625
# i=936,rest=25458, time_1_process = 0.0
# i=937,rest=25457, time_1_process = 0.015625
# i=938,rest=25456, time_1_process = 0.0
# i=939,rest=25455, time_1_process = 0.015625
# i=940,rest=25454, time_1_process = 0.0
# i=941,rest=25453, time_1_process = 0.015625
# i=942,rest=25452, time_1_process = 0.015625
# i=943,rest=25451, time_1_process = 0.0
# i=944,rest=25450, time_1_process = 0.015625
# i=945,rest=25449, time_1_process = 0.0
# i=946,rest=25448, time_1_process = 0.015625
# i=947,rest=25447, time_1_process = 0.0
# i=948,rest=25446, time_1_process = 0.015625
# i=949,rest=25445, time_1_process = 0.0
# i=950,rest=25444, time_1_process = 0.015625
# i=951,rest=25443, time_1_process = 0.0
# i=952,rest=25442, time_1_process = 0.015625
# i=953,rest=25441, time_1_process = 0.0
# i=954,rest=25440, time_1_process = 0.015625
# i=955,rest=25439, time_1_process = 0.0
# i=956,rest=25438, time_1_process = 0.0
# i=957,rest=25437, time_1_process = 0.015625
# i=958,rest=25436, time_1_process = 0.0
# i=959,rest=25435, time_1_process = 0.015625
# i=960,rest=25434, time_1_process = 0.0
# i=961,rest=25433, time_1_process = 0.015625
# i=962,rest=25432, time_1_process = 0.0
# i=963,rest=25431, time_1_process = 0.015625
# i=964,rest=25430, time_1_process = 0.0
# i=965,rest=25429, time_1_process = 0.015625
# i=966,rest=25428, time_1_process = 0.0
# i=967,rest=25427, time_1_process = 0.015625
# i=968,rest=25426, time_1_process = 0.0
# i=969,rest=25425, time_1_process = 0.0
# i=970,rest=25424, time_1_process = 0.015625
# i=971,rest=25423, time_1_process = 0.0
# i=972,rest=25422, time_1_process = 0.015625
# i=973,rest=25421, time_1_process = 0.0
# i=974,rest=25420, time_1_process = 0.015625
# i=975,rest=25419, time_1_process = 0.0
# i=976,rest=25418, time_1_process = 0.015625
# i=977,rest=25417, time_1_process = 0.0
# i=978,rest=25416, time_1_process = 0.015625
# i=979,rest=25415, time_1_process = 0.0
# i=980,rest=25414, time_1_process = 0.015625
# i=981,rest=25413, time_1_process = 0.0
# i=982,rest=25412, time_1_process = 0.0
# i=983,rest=25411, time_1_process = 0.015625
# i=984,rest=25410, time_1_process = 0.0
# i=985,rest=25409, time_1_process = 0.015625
# i=986,rest=25408, time_1_process = 0.0
# i=987,rest=25407, time_1_process = 0.015625
# i=988,rest=25406, time_1_process = 0.0
# i=989,rest=25405, time_1_process = 0.015625
# i=990,rest=25404, time_1_process = 0.0
# i=991,rest=25403, time_1_process = 0.0
# i=992,rest=25402, time_1_process = 0.015625
# i=993,rest=25401, time_1_process = 0.0
# i=994,rest=25400, time_1_process = 0.015625
# i=995,rest=25399, time_1_process = 0.0
# i=996,rest=25398, time_1_process = 0.015625
# i=997,rest=25397, time_1_process = 0.0
# i=998,rest=25396, time_1_process = 0.015625
# i=999,rest=25395, time_1_process = 0.0
# i=1000,rest=25394, time_1_process = 0.015625
# i=1001,rest=25393, time_1_process = 0.0
# i=1002,rest=25392, time_1_process = 0.0
# i=1003,rest=25391, time_1_process = 0.015625
# i=1004,rest=25390, time_1_process = 0.0
# i=1005,rest=25389, time_1_process = 0.015625
# i=1006,rest=25388, time_1_process = 0.0
# i=1007,rest=25387, time_1_process = 0.015625
# i=1008,rest=25386, time_1_process = 0.0
# i=1009,rest=25385, time_1_process = 0.015625
# i=1010,rest=25384, time_1_process = 0.0
# i=1011,rest=25383, time_1_process = 0.015625
# i=1012,rest=25382, time_1_process = 0.0
# i=1013,rest=25381, time_1_process = 0.015625
# i=1014,rest=25380, time_1_process = 0.0
# i=1015,rest=25379, time_1_process = 0.0
# i=1016,rest=25378, time_1_process = 0.015625
# i=1017,rest=25377, time_1_process = 0.0
# i=1018,rest=25376, time_1_process = 0.015625
# i=1019,rest=25375, time_1_process = 0.0
# i=1020,rest=25374, time_1_process = 0.015625
# i=1021,rest=25373, time_1_process = 0.0
# i=1022,rest=25372, time_1_process = 0.015625
# i=1023,rest=25371, time_1_process = 0.0
# i=1024,rest=25370, time_1_process = 0.015625
# i=1025,rest=25369, time_1_process = 0.0
# i=1026,rest=25368, time_1_process = 0.0
# i=1027,rest=25367, time_1_process = 0.015625
# i=1028,rest=25366, time_1_process = 0.0
# i=1029,rest=25365, time_1_process = 0.015625
# i=1030,rest=25364, time_1_process = 0.0
# i=1031,rest=25363, time_1_process = 0.015625
# i=1032,rest=25362, time_1_process = 0.0
# i=1033,rest=25361, time_1_process = 0.015625
# i=1034,rest=25360, time_1_process = 0.0
# i=1035,rest=25359, time_1_process = 0.015625
# i=1036,rest=25358, time_1_process = 0.0
# i=1037,rest=25357, time_1_process = 0.015625
# i=1038,rest=25356, time_1_process = 0.0
# i=1039,rest=25355, time_1_process = 0.015625
# i=1040,rest=25354, time_1_process = 0.0
# i=1041,rest=25353, time_1_process = 0.015625
# i=1042,rest=25352, time_1_process = 0.0
# i=1043,rest=25351, time_1_process = 0.0
# i=1044,rest=25350, time_1_process = 0.015625
# i=1045,rest=25349, time_1_process = 0.0
# i=1046,rest=25348, time_1_process = 0.015625
# i=1047,rest=25347, time_1_process = 0.0
# i=1048,rest=25346, time_1_process = 0.015625
# i=1049,rest=25345, time_1_process = 0.0
# i=1050,rest=25344, time_1_process = 0.015625
# i=1051,rest=25343, time_1_process = 0.0
# i=1052,rest=25342, time_1_process = 0.0
# i=1053,rest=25341, time_1_process = 0.015625
# i=1054,rest=25340, time_1_process = 0.0
# i=1055,rest=25339, time_1_process = 0.015625
# i=1056,rest=25338, time_1_process = 0.0
# i=1057,rest=25337, time_1_process = 0.015625
# i=1058,rest=25336, time_1_process = 0.0
# i=1059,rest=25335, time_1_process = 0.015625
# i=1060,rest=25334, time_1_process = 0.0
# i=1061,rest=25333, time_1_process = 0.015625
# i=1062,rest=25332, time_1_process = 0.0
# i=1063,rest=25331, time_1_process = 0.015625
# i=1064,rest=25330, time_1_process = 0.0
# i=1065,rest=25329, time_1_process = 0.0
# i=1066,rest=25328, time_1_process = 0.015625
# i=1067,rest=25327, time_1_process = 0.015625
# i=1068,rest=25326, time_1_process = 0.0
# i=1069,rest=25325, time_1_process = 0.015625
# i=1070,rest=25324, time_1_process = 0.0
# i=1071,rest=25323, time_1_process = 0.0
# i=1072,rest=25322, time_1_process = 0.015625
# i=1073,rest=25321, time_1_process = 0.0
# i=1074,rest=25320, time_1_process = 0.015625
# i=1075,rest=25319, time_1_process = 0.0
# i=1076,rest=25318, time_1_process = 0.015625
# i=1077,rest=25317, time_1_process = 0.0
# i=1078,rest=25316, time_1_process = 0.0
# i=1079,rest=25315, time_1_process = 0.0
# i=1080,rest=25314, time_1_process = 0.0
# i=1081,rest=25313, time_1_process = 0.015625
# i=1082,rest=25312, time_1_process = 0.0
# i=1083,rest=25311, time_1_process = 0.015625
# i=1084,rest=25310, time_1_process = 0.0
# i=1085,rest=25309, time_1_process = 0.015625
# i=1086,rest=25308, time_1_process = 0.0
# i=1087,rest=25307, time_1_process = 0.015625
# i=1088,rest=25306, time_1_process = 0.0
# i=1089,rest=25305, time_1_process = 0.015625
# i=1090,rest=25304, time_1_process = 0.0
# i=1091,rest=25303, time_1_process = 0.0
# i=1092,rest=25302, time_1_process = 0.015625
# i=1093,rest=25301, time_1_process = 0.0
# i=1094,rest=25300, time_1_process = 0.015625
# i=1095,rest=25299, time_1_process = 0.0
# i=1096,rest=25298, time_1_process = 0.015625
# i=1097,rest=25297, time_1_process = 0.0
# i=1098,rest=25296, time_1_process = 0.015625
# i=1099,rest=25295, time_1_process = 0.0
# i=1100,rest=25294, time_1_process = 0.015625
# i=1101,rest=25293, time_1_process = 0.0
# i=1102,rest=25292, time_1_process = 0.015625
# i=1103,rest=25291, time_1_process = 0.0
# i=1104,rest=25290, time_1_process = 0.0
# i=1105,rest=25289, time_1_process = 0.015625
# i=1106,rest=25288, time_1_process = 0.0
# i=1107,rest=25287, time_1_process = 0.015625
# i=1108,rest=25286, time_1_process = 0.0
# i=1109,rest=25285, time_1_process = 0.015625
# i=1110,rest=25284, time_1_process = 0.0
# i=1111,rest=25283, time_1_process = 0.015625
# i=1112,rest=25282, time_1_process = 0.0
# i=1113,rest=25281, time_1_process = 0.015625
# i=1114,rest=25280, time_1_process = 0.0
# i=1115,rest=25279, time_1_process = 0.015625
# i=1116,rest=25278, time_1_process = 0.0
# i=1117,rest=25277, time_1_process = 0.0
# i=1118,rest=25276, time_1_process = 0.015625
# i=1119,rest=25275, time_1_process = 0.0
# i=1120,rest=25274, time_1_process = 0.015625
# i=1121,rest=25273, time_1_process = 0.0
# i=1122,rest=25272, time_1_process = 0.015625
# i=1123,rest=25271, time_1_process = 0.0
# i=1124,rest=25270, time_1_process = 0.015625
# i=1125,rest=25269, time_1_process = 0.0
# i=1126,rest=25268, time_1_process = 0.015625
# i=1127,rest=25267, time_1_process = 0.0
# i=1128,rest=25266, time_1_process = 0.015625
# i=1129,rest=25265, time_1_process = 0.0
# i=1130,rest=25264, time_1_process = 0.015625
# i=1131,rest=25263, time_1_process = 0.0
# i=1132,rest=25262, time_1_process = 0.015625
# i=1133,rest=25261, time_1_process = 0.0
# i=1134,rest=25260, time_1_process = 0.0
# i=1135,rest=25259, time_1_process = 0.015625
# i=1136,rest=25258, time_1_process = 0.0
# i=1137,rest=25257, time_1_process = 0.015625
# i=1138,rest=25256, time_1_process = 0.0
# i=1139,rest=25255, time_1_process = 0.015625
# i=1140,rest=25254, time_1_process = 0.0
# i=1141,rest=25253, time_1_process = 0.0
# i=1142,rest=25252, time_1_process = 0.015625
# i=1143,rest=25251, time_1_process = 0.0
# i=1144,rest=25250, time_1_process = 0.015625
# i=1145,rest=25249, time_1_process = 0.0
# i=1146,rest=25248, time_1_process = 0.015625
# i=1147,rest=25247, time_1_process = 0.0
# i=1148,rest=25246, time_1_process = 0.015625
# i=1149,rest=25245, time_1_process = 0.0
# i=1150,rest=25244, time_1_process = 0.015625
# i=1151,rest=25243, time_1_process = 0.0
# i=1152,rest=25242, time_1_process = 0.015625
# i=1153,rest=25241, time_1_process = 0.0
# i=1154,rest=25240, time_1_process = 0.015625
# i=1155,rest=25239, time_1_process = 0.0
# i=1156,rest=25238, time_1_process = 0.0
# i=1157,rest=25237, time_1_process = 0.015625
# i=1158,rest=25236, time_1_process = 0.0
# ...
# i=4643,rest=21751, time_1_process = 0.0
# i=4644,rest=21750, time_1_process = 0.015625
# i=4645,rest=21749, time_1_process = 0.0
# i=4646,rest=21748, time_1_process = 0.015625
# i=4647,rest=21747, time_1_process = 0.0
# i=4648,rest=21746, time_1_process = 0.015625
# i=4649,rest=21745, time_1_process = 0.0
# i=4650,rest=21744, time_1_process = 0.015625
# i=4651,rest=21743, time_1_process = 0.0
# i=4652,rest=21742, time_1_process = 0.0
# i=4653,rest=21741, time_1_process = 0.0
# i=4654,rest=21740, time_1_process = 0.015625
# i=4655,rest=21739, time_1_process = 0.015625
# i=4656,rest=21738, time_1_process = 0.0
# i=4657,rest=21737, time_1_process = 0.015625
# i=4658,rest=21736, time_1_process = 0.0
# i=4659,rest=21735, time_1_process = 0.0
# i=4660,rest=21734, time_1_process = 0.015625
# i=4661,rest=21733, time_1_process = 0.015625
# i=4662,rest=21732, time_1_process = 0.0
# i=4663,rest=21731, time_1_process = 0.015625
# i=4664,rest=21730, time_1_process = 0.0
# i=4665,rest=21729, time_1_process = 0.015625
# i=4666,rest=21728, time_1_process = 0.0
# i=4667,rest=21727, time_1_process = 0.015625
# i=4668,rest=21726, time_1_process = 0.0
# i=4669,rest=21725, time_1_process = 0.015625
# i=4670,rest=21724, time_1_process = 0.0
# i=4671,rest=21723, time_1_process = 0.015625
# i=4672,rest=21722, time_1_process = 0.0
# i=4673,rest=21721, time_1_process = 0.015625
# i=4674,rest=21720, time_1_process = 0.0
# i=4675,rest=21719, time_1_process = 0.0
# i=4676,rest=21718, time_1_process = 0.015625
# i=4677,rest=21717, time_1_process = 0.0
# i=4678,rest=21716, time_1_process = 0.015625
# i=4679,rest=21715, time_1_process = 0.0
# i=4680,rest=21714, time_1_process = 0.015625
# i=4681,rest=21713, time_1_process = 0.0
# i=4682,rest=21712, time_1_process = 0.015625
# i=4683,rest=21711, time_1_process = 0.0
# i=4684,rest=21710, time_1_process = 0.015625
# i=4685,rest=21709, time_1_process = 0.0
# i=4686,rest=21708, time_1_process = 0.0
# i=4687,rest=21707, time_1_process = 0.015625
# i=4688,rest=21706, time_1_process = 0.0
# i=4689,rest=21705, time_1_process = 0.015625
# i=4690,rest=21704, time_1_process = 0.0
# i=4691,rest=21703, time_1_process = 0.015625
# i=4692,rest=21702, time_1_process = 0.0
# i=4693,rest=21701, time_1_process = 0.015625
# i=4694,rest=21700, time_1_process = 0.0
# i=4695,rest=21699, time_1_process = 0.015625
# i=4696,rest=21698, time_1_process = 0.0
# i=4697,rest=21697, time_1_process = 0.015625
# i=4698,rest=21696, time_1_process = 0.0
# i=4699,rest=21695, time_1_process = 0.015625
# i=4700,rest=21694, time_1_process = 0.015625
# i=4701,rest=21693, time_1_process = 0.0
# i=4702,rest=21692, time_1_process = 0.015625
# i=4703,rest=21691, time_1_process = 0.0
# i=4704,rest=21690, time_1_process = 0.015625
# i=4705,rest=21689, time_1_process = 0.0
# i=4706,rest=21688, time_1_process = 0.015625
# i=4707,rest=21687, time_1_process = 0.0
# i=4708,rest=21686, time_1_process = 0.0
# i=4709,rest=21685, time_1_process = 0.015625
# i=4710,rest=21684, time_1_process = 0.0
# i=4711,rest=21683, time_1_process = 0.015625
# i=4712,rest=21682, time_1_process = 0.0
# i=4713,rest=21681, time_1_process = 0.015625
# i=4714,rest=21680, time_1_process = 0.0
# i=4715,rest=21679, time_1_process = 0.015625
# i=4716,rest=21678, time_1_process = 0.0
# i=4717,rest=21677, time_1_process = 0.015625
# i=4718,rest=21676, time_1_process = 0.0
# i=4719,rest=21675, time_1_process = 0.015625
# i=4720,rest=21674, time_1_process = 0.0
# i=4721,rest=21673, time_1_process = 0.0
# i=4722,rest=21672, time_1_process = 0.0
# i=4723,rest=21671, time_1_process = 0.015625
# i=4724,rest=21670, time_1_process = 0.0
# i=4725,rest=21669, time_1_process = 0.015625
# i=4726,rest=21668, time_1_process = 0.0
# i=4727,rest=21667, time_1_process = 0.015625
# i=4728,rest=21666, time_1_process = 0.0
# i=4729,rest=21665, time_1_process = 0.015625
# i=4730,rest=21664, time_1_process = 0.0
# i=4731,rest=21663, time_1_process = 0.015625
# i=4732,rest=21662, time_1_process = 0.0
# i=4733,rest=21661, time_1_process = 0.015625
# i=4734,rest=21660, time_1_process = 0.0
# i=4735,rest=21659, time_1_process = 0.015625
# i=4736,rest=21658, time_1_process = 0.0
# i=4737,rest=21657, time_1_process = 0.015625
# i=4738,rest=21656, time_1_process = 0.0
# i=4739,rest=21655, time_1_process = 0.015625
# i=4740,rest=21654, time_1_process = 0.0
# i=4741,rest=21653, time_1_process = 0.015625
# i=4742,rest=21652, time_1_process = 0.0
# i=4743,rest=21651, time_1_process = 0.015625
# i=4744,rest=21650, time_1_process = 0.0
# i=4745,rest=21649, time_1_process = 0.015625
# i=4746,rest=21648, time_1_process = 0.0
# i=4747,rest=21647, time_1_process = 0.015625
# i=4748,rest=21646, time_1_process = 0.0
# i=4749,rest=21645, time_1_process = 0.015625
# i=4750,rest=21644, time_1_process = 0.015625
# i=4751,rest=21643, time_1_process = 0.0
# i=4752,rest=21642, time_1_process = 0.0
# i=4753,rest=21641, time_1_process = 0.015625
# i=4754,rest=21640, time_1_process = 0.015625
# i=4755,rest=21639, time_1_process = 0.0
# i=4756,rest=21638, time_1_process = 0.015625
# i=4757,rest=21637, time_1_process = 0.0
# i=4758,rest=21636, time_1_process = 0.015625
# i=4759,rest=21635, time_1_process = 0.0
# i=4760,rest=21634, time_1_process = 0.0
# i=4761,rest=21633, time_1_process = 0.015625
# i=4762,rest=21632, time_1_process = 0.0
# i=4763,rest=21631, time_1_process = 0.015625
# i=4764,rest=21630, time_1_process = 0.0
# i=4765,rest=21629, time_1_process = 0.015625
# i=4766,rest=21628, time_1_process = 0.0
# i=4767,rest=21627, time_1_process = 0.015625
# i=4768,rest=21626, time_1_process = 0.015625
# i=4769,rest=21625, time_1_process = 0.0
# i=4770,rest=21624, time_1_process = 0.0
# i=4771,rest=21623, time_1_process = 0.015625
# i=4772,rest=21622, time_1_process = 0.0
# i=4773,rest=21621, time_1_process = 0.015625
# i=4774,rest=21620, time_1_process = 0.0
# i=4775,rest=21619, time_1_process = 0.015625
# i=4776,rest=21618, time_1_process = 0.0
# i=4777,rest=21617, time_1_process = 0.015625
# i=4778,rest=21616, time_1_process = 0.0
# i=4779,rest=21615, time_1_process = 0.015625
# i=4780,rest=21614, time_1_process = 0.0
# i=4781,rest=21613, time_1_process = 0.015625
# i=4782,rest=21612, time_1_process = 0.0
# i=4783,rest=21611, time_1_process = 0.015625
# i=4784,rest=21610, time_1_process = 0.0
# i=4785,rest=21609, time_1_process = 0.015625
# i=4786,rest=21608, time_1_process = 0.0
# i=4787,rest=21607, time_1_process = 0.015625
# i=4788,rest=21606, time_1_process = 0.0
# i=4789,rest=21605, time_1_process = 0.0
# i=4790,rest=21604, time_1_process = 0.015625
# i=4791,rest=21603, time_1_process = 0.0
# i=4792,rest=21602, time_1_process = 0.015625
# i=4793,rest=21601, time_1_process = 0.0
# i=4794,rest=21600, time_1_process = 0.015625
# i=4795,rest=21599, time_1_process = 0.0
# i=4796,rest=21598, time_1_process = 0.015625
# i=4797,rest=21597, time_1_process = 0.0
# i=4798,rest=21596, time_1_process = 0.015625
# i=4799,rest=21595, time_1_process = 0.0
# i=4800,rest=21594, time_1_process = 0.015625
# i=4801,rest=21593, time_1_process = 0.0
# i=4802,rest=21592, time_1_process = 0.015625
# i=4803,rest=21591, time_1_process = 0.0
# i=4804,rest=21590, time_1_process = 0.015625
# i=4805,rest=21589, time_1_process = 0.0
# i=4806,rest=21588, time_1_process = 0.015625
# i=4807,rest=21587, time_1_process = 0.0
# i=4808,rest=21586, time_1_process = 0.0
# i=4809,rest=21585, time_1_process = 0.015625
# i=4810,rest=21584, time_1_process = 0.0
# i=4811,rest=21583, time_1_process = 0.015625
# i=4812,rest=21582, time_1_process = 0.0
# i=4813,rest=21581, time_1_process = 0.015625
# i=4814,rest=21580, time_1_process = 0.0
# i=4815,rest=21579, time_1_process = 0.015625
# i=4816,rest=21578, time_1_process = 0.0
# i=4817,rest=21577, time_1_process = 0.0
# i=4818,rest=21576, time_1_process = 0.015625
# i=4819,rest=21575, time_1_process = 0.015625
# i=4820,rest=21574, time_1_process = 0.0
# i=4821,rest=21573, time_1_process = 0.0
# i=4822,rest=21572, time_1_process = 0.015625
# i=4823,rest=21571, time_1_process = 0.0
# i=4824,rest=21570, time_1_process = 0.015625
# i=4825,rest=21569, time_1_process = 0.0
# i=4826,rest=21568, time_1_process = 0.015625
# i=4827,rest=21567, time_1_process = 0.0
# i=4828,rest=21566, time_1_process = 0.015625
# i=4829,rest=21565, time_1_process = 0.0
# i=4830,rest=21564, time_1_process = 0.015625
# i=4831,rest=21563, time_1_process = 0.0
# i=4832,rest=21562, time_1_process = 0.0
# i=4833,rest=21561, time_1_process = 0.015625
# i=4834,rest=21560, time_1_process = 0.0
# i=4835,rest=21559, time_1_process = 0.015625
# i=4836,rest=21558, time_1_process = 0.0
# i=4837,rest=21557, time_1_process = 0.015625
# i=4838,rest=21556, time_1_process = 0.0
# i=4839,rest=21555, time_1_process = 0.015625
# i=4840,rest=21554, time_1_process = 0.0
# i=4841,rest=21553, time_1_process = 0.015625
# i=4842,rest=21552, time_1_process = 0.0
# i=4843,rest=21551, time_1_process = 0.015625
# i=4844,rest=21550, time_1_process = 0.0
# i=4845,rest=21549, time_1_process = 0.015625
# i=4846,rest=21548, time_1_process = 0.0
# i=4847,rest=21547, time_1_process = 0.015625
# i=4848,rest=21546, time_1_process = 0.0
# i=4849,rest=21545, time_1_process = 0.015625
# i=4850,rest=21544, time_1_process = 0.0
# i=4851,rest=21543, time_1_process = 0.0
# i=4852,rest=21542, time_1_process = 0.015625
# i=4853,rest=21541, time_1_process = 0.0
# i=4854,rest=21540, time_1_process = 0.015625
# i=4855,rest=21539, time_1_process = 0.0
# i=4856,rest=21538, time_1_process = 0.015625
# i=4857,rest=21537, time_1_process = 0.0
# i=4858,rest=21536, time_1_process = 0.015625
# i=4859,rest=21535, time_1_process = 0.0
# i=4860,rest=21534, time_1_process = 0.015625
# i=4861,rest=21533, time_1_process = 0.0
# i=4862,rest=21532, time_1_process = 0.0
# i=4863,rest=21531, time_1_process = 0.015625
# i=4864,rest=21530, time_1_process = 0.0
# i=4865,rest=21529, time_1_process = 0.015625
# i=4866,rest=21528, time_1_process = 0.0
# i=4867,rest=21527, time_1_process = 0.015625
# i=4868,rest=21526, time_1_process = 0.0
# i=4869,rest=21525, time_1_process = 0.015625
# i=4870,rest=21524, time_1_process = 0.0
# i=4871,rest=21523, time_1_process = 0.0
# i=4872,rest=21522, time_1_process = 0.015625
# i=4873,rest=21521, time_1_process = 0.0
# i=4874,rest=21520, time_1_process = 0.015625
# i=4875,rest=21519, time_1_process = 0.0
# i=4876,rest=21518, time_1_process = 0.015625
# i=4877,rest=21517, time_1_process = 0.0
# i=4878,rest=21516, time_1_process = 0.015625
# i=4879,rest=21515, time_1_process = 0.0
# i=4880,rest=21514, time_1_process = 0.015625
# i=4881,rest=21513, time_1_process = 0.0
# i=4882,rest=21512, time_1_process = 0.0
# i=4883,rest=21511, time_1_process = 0.015625
# i=4884,rest=21510, time_1_process = 0.0
# i=4885,rest=21509, time_1_process = 0.015625
# i=4886,rest=21508, time_1_process = 0.0
# i=4887,rest=21507, time_1_process = 0.015625
# i=4888,rest=21506, time_1_process = 0.0
# i=4889,rest=21505, time_1_process = 0.015625
# i=4890,rest=21504, time_1_process = 0.0
# i=4891,rest=21503, time_1_process = 0.015625
# i=4892,rest=21502, time_1_process = 0.0
# i=4893,rest=21501, time_1_process = 0.015625
# i=4894,rest=21500, time_1_process = 0.0
# i=4895,rest=21499, time_1_process = 0.015625
# i=4896,rest=21498, time_1_process = 0.0
# i=4897,rest=21497, time_1_process = 0.015625
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Alencar\Documents\GitHub\MAAED-main\python-dependency\src\fix_data.ipynb Cell 12 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Alencar/Documents/GitHub/MAAED-main/python-dependency/src/fix_data.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> t1_start = process_time()
#       <a href='vscode-notebook-cell:/c%3A/Users/Alencar/Documents/GitHub/MAAED-main/python-dependency/src/fix_data.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a> index_element = df_nodes["index"].iloc[(df_nodes['package'] == df_nodes.iloc[i,1]).idxmax()]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alencar/Documents/GitHub/MAAED-main/python-dependency/src/fix_data.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> df_edge.replace(to_replace=df_nodes.iloc[i,1],value=index_element,inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Alencar/Documents/GitHub/MAAED-main/python-dependency/src/fix_data.ipynb#X14sZmlsZQ%3D%3D?line=6'>7</a> t1_stop = process_time()
#       <a href='vscode-notebook-cell:/c%3A/Users/Alencar/Documents/GitHub/MAAED-main/python-dependency/src/fix_data.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> print(f"i={i},rest={N-i}, time_1_process = {t1_stop - t1_start}")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5582, in DataFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    5571 @doc(NDFrame.replace, **_shared_doc_kwargs)
#    5572 def replace(
#    5573     self,
#    (...)
#    5580     method: Literal["pad", "ffill", "bfill"] | lib.NoDefault = lib.no_default,
#    5581 ) -> DataFrame | None:
# -> 5582     return super().replace(
#    5583         to_replace=to_replace,
#    5584         value=value,
#    5585         inplace=inplace,
#    5586         limit=limit,
#    5587         regex=regex,
#    5588         method=method,
#    5589     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:7389, in NDFrame.replace(self, to_replace, value, inplace, limit, regex, method)
#    7383         new_data = self._mgr.replace_regex(
#    7384             to_replace=to_replace,
#    7385             value=value,
#    7386             inplace=inplace,
#    7387         )
#    7388     else:
# -> 7389         new_data = self._mgr.replace(
#    7390             to_replace=to_replace, value=value, inplace=inplace
#    7391         )
#    7392 else:
#    7393     raise TypeError(
#    7394         f'Invalid "to_replace" type: {repr(type(to_replace).__name__)}'
#    7395     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:475, in BaseBlockManager.replace(self, to_replace, value, inplace)
#     473 assert not is_list_like(to_replace)
#     474 assert not is_list_like(value)
# --> 475 return self.apply(
#     476     "replace",
#     477     to_replace=to_replace,
#     478     value=value,
#     479     inplace=inplace,
#     480     using_cow=using_copy_on_write(),
#     481 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\internals\blocks.py:593, in Block.replace(self, to_replace, value, inplace, mask, using_cow)
#     590         return [self] if inplace else [self.copy()]
#     592 if mask is None:
# --> 593     mask = missing.mask_missing(values, to_replace)
#     594 if not mask.any():
#     595     # Note: we get here with test_replace_extension_other incorrectly
#     596     #  bc _can_hold_element is incorrect.
#     597     if using_cow:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\missing.py:94, in mask_missing(arr, values_to_mask)
#      91     potential_na = True
#      92     arr_mask = ~isna(arr)
# ---> 94 na_mask = isna(values_to_mask)
#      95 nonna = values_to_mask[~na_mask]
#      97 # GH 21977
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\dtypes\missing.py:106, in isna(obj)
#     101 @overload
#     102 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     103     ...
# --> 106 def isna(obj: object) -> bool | npt.NDArray[np.bool_] | NDFrame:
#     107     """
#     108     Detect missing values for an array-like object.
#     109
#    (...)
#     181     Name: 1, dtype: bool
#     182     """
#     183     return _isna(obj)
#
# KeyboardInterrupt:

# %%
df_edge.to_csv("../data/edges.csv",index=False,mode="w")
